# %%
import csv
import pandas as pd

# %%
df=pd.read_csv('Child Labour in India (1).csv')

# %%
df.shape
# Out:
# (22, 9)

# %%
df
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 0   Non Special Category states  Andhra Pradesh         69.0           9.7
# 1   Non Special Category states           Assam         69.3           8.4
# 2   Non Special Category states           Bihar         71.8          11.2
# 3   Non Special Category states    Chhattisgarh         87.9           2.4
# 4   Non Special Category states           Delhi          0.0          11.1
# 5   Non Special Category states         Gujarat         76.7           2.6
# 6   Non Special Category states         Haryana         65.6           3.8
# 7   Non Special Category states       Jharkhand         65.3          14.6
# 8   Non Special Category states       Karnataka         82.6           9.3
# 9   Non Special Category states          Kerala         19.2          32.8
# 10  Non Special Category states  Madhya Pradesh         82.9          9. 9
# 11  Non Special Category states     Maharashtra         82.6           5.3
# 12  Non Special Category states          Orissa         73.2          17.4
# 13  Non Special Category states          Punjab         67.9          12.7
# 14  Non Special Category states       Rajasthan         75.8           9.6
# 15  Non Special Category states      Tamil Nadu         39.5          44.6
# 16  Non Special Category states   Uttar Pradesh         61.2          25.3
# 17  Non Special Category states     West Bengal         34.6          43.9
# 18                          NaN             NaN          NaN           NaN
# 19      Special Category States     Uttarakhand         80.7           4.7
# 20                          NaN             NaN          NaN           NaN
# 21                    All India       All India         68.1          16.6
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 1            1.8                         7.8
# 2            0.0                        15.5
# 3            0.9                         7.2
# 4            0.0                        57.8
# 5            0.3                        17.8
# 6            7.0                         8.1
# 7            4.3                        12.1
# 8            1.2                         5.7
# 9            0.0                        32.0
# 10           1.5                         4.3
# 11           1.9                         5.8
# 12           3.3                         3.3
# 13           1.2                         7.2
# 14           2.9                         7.3
# 15           5.9                         5.7
# 16           0.4                         9.7
# 17           3.3                         9.7
# 18           NaN                         NaN
# 19           5.2                         9.3
# 20           NaN                         NaN
# 21           2.0                         8.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0  100.0
# 1                                      11.0     1.8  100.0
# 2                                       1.1     0.5  100.0
# 3                                       1.7     0.0  100.0
# 4                                      31.1     0.0  100.0
# 5                                       1.5     1.2  100.0
# 6                                      15.5     0.0  100.0
# 7                                       2.8     0.9  100.0
# 8                                       0.3     0.9  100.0
# 9                                      16.1     0.0  100.0
# 10                                      1.3     0.0  100.0
# 11                                      4.1     0.3  100.0
# 12                                      1.1     1.8  100.0
# 13                                      8.4     2.6  100.0
# 14                                      0.4     4.0  100.0
# 15                                      2.7     1.7  100.0
# 16                                      2.1     1.2  100.0
# 17                                      6.6     2.0  100.0
# 18                                      NaN     NaN    NaN
# 19                                      0.0     0.0  100.0
# 20                                      NaN     NaN    NaN
# 21                                      3.4     1.5  100.0

# %%
# Open the input CSV file in read mode
with open('Child Labour in India (1).csv', 'r', newline='') as infile:
    reader = csv.reader(infile)

    # Filter out empty lines
    cleaned_data = [row for row in reader if all(field.strip() for field in row)]

# %%
with open('output.csv', 'w', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(cleaned_data)

# %%
df1=pd.read_csv('output.csv')

# %%
df1
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 0   Non Special Category states  Andhra Pradesh         69.0           9.7
# 1   Non Special Category states           Assam         69.3           8.4
# 2   Non Special Category states           Bihar         71.8          11.2
# 3   Non Special Category states    Chhattisgarh         87.9           2.4
# 4   Non Special Category states           Delhi          0.0          11.1
# 5   Non Special Category states         Gujarat         76.7           2.6
# 6   Non Special Category states         Haryana         65.6           3.8
# 7   Non Special Category states       Jharkhand         65.3          14.6
# 8   Non Special Category states       Karnataka         82.6           9.3
# 9   Non Special Category states          Kerala         19.2          32.8
# 10  Non Special Category states  Madhya Pradesh         82.9          9. 9
# 11  Non Special Category states     Maharashtra         82.6           5.3
# 12  Non Special Category states          Orissa         73.2          17.4
# 13  Non Special Category states          Punjab         67.9          12.7
# 14  Non Special Category states       Rajasthan         75.8           9.6
# 15  Non Special Category states      Tamil Nadu         39.5          44.6
# 16  Non Special Category states   Uttar Pradesh         61.2          25.3
# 17  Non Special Category states     West Bengal         34.6          43.9
# 18      Special Category States     Uttarakhand         80.7           4.7
# 19                    All India       All India         68.1          16.6
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 1            1.8                         7.8
# 2            0.0                        15.5
# 3            0.9                         7.2
# 4            0.0                        57.8
# 5            0.3                        17.8
# 6            7.0                         8.1
# 7            4.3                        12.1
# 8            1.2                         5.7
# 9            0.0                        32.0
# 10           1.5                         4.3
# 11           1.9                         5.8
# 12           3.3                         3.3
# 13           1.2                         7.2
# 14           2.9                         7.3
# 15           5.9                         5.7
# 16           0.4                         9.7
# 17           3.3                         9.7
# 18           5.2                         9.3
# 19           2.0                         8.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0    100
# 1                                      11.0     1.8    100
# 2                                       1.1     0.5    100
# 3                                       1.7     0.0    100
# 4                                      31.1     0.0    100
# 5                                       1.5     1.2    100
# 6                                      15.5     0.0    100
# 7                                       2.8     0.9    100
# 8                                       0.3     0.9    100
# 9                                      16.1     0.0    100
# 10                                      1.3     0.0    100
# 11                                      4.1     0.3    100
# 12                                      1.1     1.8    100
# 13                                      8.4     2.6    100
# 14                                      0.4     4.0    100
# 15                                      2.7     1.7    100
# 16                                      2.1     1.2    100
# 17                                      6.6     2.0    100
# 18                                      0.0     0.0    100
# 19                                      3.4     1.5    100
